# %% [markdown]
# #Paquetes necesarios

# %%
pip install Pillow

# %%
pip install tk

# %%
from tkinter import *
import cv2 
from PIL import Image, ImageTk 
import imutils
import math 
from ultralytics import YOLO

def open_camera(): 
    global vid
	# Capture the video frame by frame 
    ret, frame = vid.read() 
    if ret == True:
        results = model(frame, stream=True)
        for r in results:
            boxes = r.boxes

            for box in boxes:

                cls = int(box.cls[0])
                # Contenedor
                if classNames[cls] == "person" or classNames[cls] == "bus":
                    x1, y1, x2, y2 = box.xyxy[0]
                    x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values
                    
                    

                    # Convierte identificador numérico de clase a un color RGB
                    escala = int((cls / len(classNames)) * 255 * 3)
                    if escala >= 255*2:
                        R = 255
                        G = 255
                        B = escala - 255*2
                    else:
                        if escala >= 255:
                            R = 255
                            G = escala - 255
                            B = 0
                        else:
                            R = escala
                            G = 0
                            B = 0

                    # Dibuja el contenedor y clase
                    cv2.rectangle(frame, (x1, y1), (x2, y2), (R, G, B), 3)
                    cv2.putText(frame, classNames[cls] , [x1, y1], cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, B), 2)

        frame = imutils.resize(frame,width=640)
	    # Convert image from one color space to other 
        opencv_image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGBA) 

	    # Capture the latest frame and transform to image 
        captured_image = Image.fromarray(opencv_image) 

        # Convert captured image to photoimage 
        photo_image = ImageTk.PhotoImage(image=captured_image) 

	    # Displaying photoimage in the label 
        label_widget.photo_image = photo_image 

        # Configure image in the label 
        label_widget.configure(image=photo_image) 

	    # Repeat the same process after every 10 seconds 
        label_widget.after(10, open_camera) 
# Carga del modelo
model = YOLO('yolov8n.pt') #Contenedores

# Nombre de las distintas clases
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "giraffe", "backpack", "umbrella",
              "handbag", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]


vid = cv2.VideoCapture('Bus.mp4') 



app = Tk() 
app.bind('<Escape>', lambda e: app.quit()) 

label_widget = Label(app, text="Número de personas que se suben al bus: ")
label_widget.pack()

button_analyze = Button(app, text="Análisis")
button_analyze.pack()
label_widget = Label(app) 
label_widget.pack() 
open_camera()
app.mainloop()
# Out:
# 0: 384x640 13 persons, 1 bus, 119.2ms
# Speed: 0.0ms preprocess, 119.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 bus, 102.6ms
# Speed: 2.0ms preprocess, 102.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 2 buss, 84.8ms
# Speed: 0.0ms preprocess, 84.8ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 2 buss, 88.4ms
# Speed: 0.0ms preprocess, 88.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 82.6ms
# Speed: 0.3ms preprocess, 82.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 bus, 67.9ms
# Speed: 1.0ms preprocess, 67.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 71.1ms
# Speed: 0.0ms preprocess, 71.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 bus, 76.4ms
# Speed: 0.7ms preprocess, 76.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 bus, 69.8ms
# Speed: 2.0ms preprocess, 69.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 bus, 82.3ms
# Speed: 0.0ms preprocess, 82.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 car, 1 bus, 86.7ms
# Speed: 2.0ms preprocess, 86.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 car, 1 bus, 82.5ms
# Speed: 1.0ms preprocess, 82.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 car, 1 bus, 78.9ms
# Speed: 1.9ms preprocess, 78.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 car, 1 bus, 82.0ms
# Speed: 2.0ms preprocess, 82.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 car, 1 bus, 1 traffic light, 118.8ms
# Speed: 0.0ms preprocess, 118.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 1 bus, 91.4ms
# Speed: 2.9ms preprocess, 91.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 1 bus, 77.1ms
# Speed: 2.0ms preprocess, 77.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 1 bus, 82.2ms
# Speed: 0.0ms preprocess, 82.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 1 bus, 75.1ms
# Speed: 1.0ms preprocess, 75.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 car, 1 bus, 84.7ms
# Speed: 0.0ms preprocess, 84.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 2 cars, 1 bus, 98.9ms
# Speed: 2.0ms preprocess, 98.9ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 car, 1 bus, 71.6ms
# Speed: 5.2ms preprocess, 71.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 car, 1 bus, 63.6ms
# Speed: 2.0ms preprocess, 63.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 car, 1 bus, 64.1ms
# Speed: 1.0ms preprocess, 64.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 car, 1 bus, 78.1ms
# Speed: 2.0ms preprocess, 78.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 car, 1 bus, 64.6ms
# Speed: 1.0ms preprocess, 64.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 1 bus, 62.9ms
# Speed: 2.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 car, 1 bus, 1 handbag, 95.4ms
# Speed: 0.0ms preprocess, 95.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 car, 1 bus, 1 handbag, 79.9ms
# Speed: 2.1ms preprocess, 79.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 1 bus, 92.5ms
# Speed: 1.0ms preprocess, 92.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 car, 1 bus, 86.0ms
# Speed: 2.0ms preprocess, 86.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 car, 1 bus, 94.4ms
# Speed: 1.0ms preprocess, 94.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 car, 1 bus, 84.8ms
# Speed: 0.0ms preprocess, 84.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 car, 1 bus, 85.8ms
# Speed: 0.5ms preprocess, 85.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 2 cars, 1 bus, 82.7ms
# Speed: 1.0ms preprocess, 82.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 car, 1 bus, 84.0ms
# Speed: 0.0ms preprocess, 84.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 1 bus, 86.6ms
# Speed: 0.0ms preprocess, 86.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 1 bus, 78.0ms
# Speed: 2.0ms preprocess, 78.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 car, 1 bus, 64.9ms
# Speed: 0.2ms preprocess, 64.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 car, 1 bus, 62.5ms
# Speed: 1.4ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 car, 1 bus, 63.9ms
# Speed: 1.0ms preprocess, 63.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 1 bus, 63.5ms
# Speed: 2.0ms preprocess, 63.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 car, 1 bus, 69.2ms
# Speed: 15.2ms preprocess, 69.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 car, 1 bus, 76.5ms
# Speed: 1.8ms preprocess, 76.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 1 bus, 71.6ms
# Speed: 1.0ms preprocess, 71.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 1 bus, 68.0ms
# Speed: 0.0ms preprocess, 68.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 car, 1 bus, 64.2ms
# Speed: 2.0ms preprocess, 64.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 1 bus, 64.6ms
# Speed: 0.2ms preprocess, 64.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 2 cars, 1 bus, 78.3ms
# Speed: 2.5ms preprocess, 78.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 car, 1 bus, 95.6ms
# Speed: 0.8ms preprocess, 95.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 1 bus, 76.6ms
# Speed: 3.0ms preprocess, 76.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 car, 1 bus, 82.2ms
# Speed: 1.4ms preprocess, 82.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 car, 1 bus, 84.5ms
# Speed: 2.0ms preprocess, 84.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 car, 1 bus, 85.8ms
# Speed: 2.4ms preprocess, 85.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 car, 1 bus, 95.3ms
# Speed: 3.1ms preprocess, 95.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 car, 1 bus, 77.7ms
# Speed: 1.0ms preprocess, 77.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 1 bus, 63.9ms
# Speed: 2.0ms preprocess, 63.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 car, 1 bus, 1 traffic light, 84.9ms
# Speed: 1.0ms preprocess, 84.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 1 bus, 1 traffic light, 58.6ms
# Speed: 2.2ms preprocess, 58.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 1 bus, 1 traffic light, 61.8ms
# Speed: 0.0ms preprocess, 61.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 1 bus, 1 traffic light, 64.3ms
# Speed: 1.0ms preprocess, 64.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 car, 1 bus, 1 traffic light, 63.7ms
# Speed: 1.0ms preprocess, 63.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 1 bus, 1 traffic light, 68.9ms
# Speed: 1.0ms preprocess, 68.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 car, 1 bus, 1 traffic light, 110.7ms
# Speed: 2.0ms preprocess, 110.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 1 bus, 1 traffic light, 72.4ms
# Speed: 2.0ms preprocess, 72.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 1 bus, 1 traffic light, 71.3ms
# Speed: 1.5ms preprocess, 71.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 car, 1 bus, 1 traffic light, 72.3ms
# Speed: 2.6ms preprocess, 72.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 1 bus, 1 traffic light, 62.4ms
# Speed: 2.0ms preprocess, 62.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 1 bus, 1 traffic light, 69.4ms
# Speed: 3.2ms preprocess, 69.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 1 bus, 1 traffic light, 59.9ms
# Speed: 1.0ms preprocess, 59.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 car, 1 bus, 1 traffic light, 82.8ms
# Speed: 0.0ms preprocess, 82.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 1 bus, 1 traffic light, 79.8ms
# Speed: 1.3ms preprocess, 79.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 car, 1 bus, 63.5ms
# Speed: 0.0ms preprocess, 63.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 car, 1 bus, 62.3ms
# Speed: 4.5ms preprocess, 62.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 car, 1 bus, 67.1ms
# Speed: 2.2ms preprocess, 67.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 1 bus, 65.3ms
# Speed: 0.0ms preprocess, 65.3ms inference, 12.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 car, 1 bus, 64.5ms
# Speed: 0.0ms preprocess, 64.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 car, 1 bus, 66.4ms
# Speed: 0.0ms preprocess, 66.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 car, 1 bus, 65.1ms
# Speed: 0.0ms preprocess, 65.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 car, 1 bus, 78.2ms
# Speed: 0.0ms preprocess, 78.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 1 bus, 76.4ms
# Speed: 1.0ms preprocess, 76.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 1 bus, 66.5ms
# Speed: 0.0ms preprocess, 66.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 car, 1 bus, 68.7ms
# Speed: 0.0ms preprocess, 68.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 car, 1 bus, 68.5ms
# Speed: 0.0ms preprocess, 68.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 car, 1 bus, 67.0ms
# Speed: 0.0ms preprocess, 67.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 car, 1 bus, 65.6ms
# Speed: 0.0ms preprocess, 65.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 car, 1 bus, 49.3ms
# Speed: 0.0ms preprocess, 49.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 1 bus, 64.2ms
# Speed: 1.1ms preprocess, 64.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 car, 1 bus, 50.9ms
# Speed: 1.0ms preprocess, 50.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 car, 1 bus, 1 traffic light, 77.0ms
# Speed: 2.5ms preprocess, 77.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 car, 1 bus, 83.3ms
# Speed: 0.0ms preprocess, 83.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 car, 1 bus, 72.0ms
# Speed: 0.0ms preprocess, 72.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 car, 1 bus, 64.9ms
# Speed: 0.0ms preprocess, 64.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 car, 1 bus, 1 handbag, 59.5ms
# Speed: 0.0ms preprocess, 59.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 car, 1 bus, 1 handbag, 82.0ms
# Speed: 0.0ms preprocess, 82.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 car, 1 bus, 1 handbag, 76.8ms
# Speed: 0.0ms preprocess, 76.8ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 car, 1 bus, 73.9ms
# Speed: 0.0ms preprocess, 73.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 car, 1 bus, 79.9ms
# Speed: 3.7ms preprocess, 79.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 1 bus, 1 handbag, 72.1ms
# Speed: 0.0ms preprocess, 72.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 car, 1 bus, 65.8ms
# Speed: 0.0ms preprocess, 65.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 car, 1 bus, 1 handbag, 82.5ms
# Speed: 0.0ms preprocess, 82.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 car, 1 bus, 63.0ms
# Speed: 1.0ms preprocess, 63.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 car, 1 bus, 68.2ms
# Speed: 0.0ms preprocess, 68.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 car, 1 bus, 1 handbag, 75.9ms
# Speed: 2.0ms preprocess, 75.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 car, 1 bus, 82.2ms
# Speed: 0.0ms preprocess, 82.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 car, 1 bus, 1 handbag, 77.5ms
# Speed: 0.0ms preprocess, 77.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 car, 1 bus, 75.6ms
# Speed: 0.0ms preprocess, 75.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 car, 1 bus, 65.6ms
# Speed: 0.0ms preprocess, 65.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 car, 1 bus, 68.5ms
# Speed: 0.0ms preprocess, 68.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 car, 1 bus, 65.3ms
# Speed: 0.0ms preprocess, 65.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 car, 1 bus, 68.9ms
# Speed: 0.0ms preprocess, 68.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 car, 1 bus, 63.1ms
# Speed: 0.0ms preprocess, 63.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 car, 1 bus, 1 handbag, 70.8ms
# Speed: 2.0ms preprocess, 70.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 car, 1 bus, 83.8ms
# Speed: 0.0ms preprocess, 83.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 car, 1 bus, 65.4ms
# Speed: 0.0ms preprocess, 65.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 car, 1 bus, 68.8ms
# Speed: 15.1ms preprocess, 68.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 1 bus, 101.6ms
# Speed: 1.7ms preprocess, 101.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 1 bus, 66.6ms
# Speed: 0.0ms preprocess, 66.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 1 bus, 63.0ms
# Speed: 2.4ms preprocess, 63.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 1 bus, 102.5ms
# Speed: 4.0ms preprocess, 102.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 1 bus, 71.8ms
# Speed: 4.0ms preprocess, 71.8ms inference, 14.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 car, 1 bus, 61.1ms
# Speed: 2.3ms preprocess, 61.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 car, 1 bus, 65.2ms
# Speed: 0.0ms preprocess, 65.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 1 bus, 63.9ms
# Speed: 1.0ms preprocess, 63.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 1 bus, 65.5ms
# Speed: 0.0ms preprocess, 65.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 car, 1 bus, 66.0ms
# Speed: 0.0ms preprocess, 66.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 car, 1 bus, 97.8ms
# Speed: 1.5ms preprocess, 97.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 car, 1 bus, 76.7ms
# Speed: 1.0ms preprocess, 76.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 car, 1 bus, 64.2ms
# Speed: 1.0ms preprocess, 64.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 car, 1 bus, 63.1ms
# Speed: 1.9ms preprocess, 63.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 car, 1 bus, 1 handbag, 65.6ms
# Speed: 0.0ms preprocess, 65.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bus, 1 handbag, 64.0ms
# Speed: 1.0ms preprocess, 64.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bus, 67.2ms
# Speed: 0.0ms preprocess, 67.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bus, 86.8ms
# Speed: 2.0ms preprocess, 86.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 bus, 62.6ms
# Speed: 1.5ms preprocess, 62.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bus, 66.2ms
# Speed: 0.0ms preprocess, 66.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 bus, 64.9ms
# Speed: 1.0ms preprocess, 64.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 bus, 68.7ms
# Speed: 14.3ms preprocess, 68.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bus, 64.7ms
# Speed: 1.0ms preprocess, 64.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 bus, 65.0ms
# Speed: 0.0ms preprocess, 65.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 bus, 65.7ms
# Speed: 0.0ms preprocess, 65.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bus, 1 handbag, 66.0ms
# Speed: 0.0ms preprocess, 66.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 bus, 1 handbag, 67.2ms
# Speed: 0.0ms preprocess, 67.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bus, 2 handbags, 63.5ms
# Speed: 2.0ms preprocess, 63.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bus, 1 handbag, 49.9ms
# Speed: 0.0ms preprocess, 49.9ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bus, 2 handbags, 68.4ms
# Speed: 0.0ms preprocess, 68.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bus, 1 handbag, 67.4ms
# Speed: 0.0ms preprocess, 67.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bus, 1 handbag, 66.7ms
# Speed: 1.6ms preprocess, 66.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bus, 1 handbag, 84.8ms
# Speed: 0.0ms preprocess, 84.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bus, 3 handbags, 61.5ms
# Speed: 1.0ms preprocess, 61.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 bus, 2 handbags, 79.3ms
# Speed: 0.0ms preprocess, 79.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bus, 2 handbags, 1 clock, 80.0ms
# Speed: 2.2ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bus, 2 handbags, 1 clock, 119.4ms
# Speed: 2.0ms preprocess, 119.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bus, 1 handbag, 64.4ms
# Speed: 2.3ms preprocess, 64.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bus, 1 handbag, 65.6ms
# Speed: 0.6ms preprocess, 65.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bus, 2 handbags, 73.0ms
# Speed: 7.0ms preprocess, 73.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bus, 1 handbag, 66.2ms
# Speed: 1.0ms preprocess, 66.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bus, 3 handbags, 67.4ms
# Speed: 0.0ms preprocess, 67.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bus, 3 handbags, 68.6ms
# Speed: 0.0ms preprocess, 68.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bus, 3 handbags, 66.6ms
# Speed: 0.0ms preprocess, 66.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bus, 3 handbags, 67.1ms
# Speed: 0.0ms preprocess, 67.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bus, 2 handbags, 64.7ms
# Speed: 0.0ms preprocess, 64.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bus, 2 handbags, 64.0ms
# Speed: 0.0ms preprocess, 64.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bus, 2 handbags, 88.8ms
# Speed: 15.2ms preprocess, 88.8ms inference, 13.1ms postprocess per image at shape (1, 3, 384, 640)
